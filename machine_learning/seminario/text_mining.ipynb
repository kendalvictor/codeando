# %% [markdown]
# # Pre seminario URP

# %% [markdown]
# ## xvr!!

# %%
import wordcloud

# %%
import numpy as np # linear algebra
import pandas as pd 
import matplotlib as mpl
print(mpl.get_cachedir())
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/villacorta/.cache/matplotlib

# %%
mpl.rcParams['font.size']=12                #10 
mpl.rcParams['savefig.dpi']=100             #72 
mpl.rcParams['figure.subplot.bottom']=.1

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-07d5778700e4> in <module>()
# ----> 1 stopwords = set(STOPWORDS)
#       2 data = pd.read_csv("/home/villacorta/STORAGE/encode/URP_NLP/Sheet_1.csv")
#
# NameError: name 'STOPWORDS' is not defined

# %%
from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS

# %%
stopwords = set(STOPWORDS)
data = pd.read_csv("/home/villacorta/STORAGE/encode/URP_NLP/Sheet_1.csv")
print(data)
# Out:
#     response_id        class  \
# 0    response_1  not_flagged
# 1    response_2      flagged
# 2    response_3      flagged
# 3    response_4  not_flagged
# 4    response_5  not_flagged
# 5    response_6  not_flagged
# 6    response_7      flagged
# 7    response_8      flagged
# 8    response_9  not_flagged
# 9   response_10      flagged
# 10  response_11  not_flagged
# 11  response_12      flagged
# 12  response_13  not_flagged
# 13  response_14  not_flagged
# 14  response_15  not_flagged
# 15  response_16      flagged
# 16  response_17  not_flagged
# 17  response_18  not_flagged
# 18  response_19  not_flagged
# 19  response_20  not_flagged
# 20  response_21  not_flagged
# 21  response_22      flagged
# 22  response_23      flagged
# 23  response_24  not_flagged
# 24  response_25  not_flagged
# 25  response_26      flagged
# 26  response_27      flagged
# 27  response_28  not_flagged
# 28  response_29      flagged
# 29  response_30  not_flagged
# ..          ...          ...
# 50  response_51  not_flagged
# 51  response_52      flagged
# 52  response_53  not_flagged
# 53  response_54  not_flagged
# 54  response_55  not_flagged
# 55  response_56  not_flagged
# 56  response_57  not_flagged
# 57  response_58      flagged
# 58  response_59  not_flagged
# 59  response_60      flagged
# 60  response_61  not_flagged
# 61  response_62      flagged
# 62  response_63  not_flagged
# 63  response_64  not_flagged
# 64  response_65      flagged
# 65  response_66  not_flagged
# 66  response_67  not_flagged
# 67  response_68  not_flagged
# 68  response_69  not_flagged
# 69  response_70  not_flagged
# 70  response_71  not_flagged
# 71  response_72  not_flagged
# 72  response_73      flagged
# 73  response_74  not_flagged
# 74  response_75      flagged
# 75  response_76  not_flagged
# 76  response_77      flagged
# 77  response_78  not_flagged
# 78  response_79      flagged
# 79  response_80  not_flagged
#
#                                         response_text  \
# 0               I try and avoid this sort of conflict
# 1   Had a friend open up to me about his mental ad...
# 2   I saved a girl from suicide once. She was goin...
# 3   i cant think of one really...i think i may hav...
# 4   Only really one friend who doesn't fit into th...
# 5   a couple of years ago my friends was going to ...
# 6   Roommate when he was going through death and l...
# 7   i've had a couple of friends (you could say mo...
# 8   Listened to someone talk about relationship tr...
# 9   I will always listen. I comforted my sister wh...
# 10  Took a week off work, packed up the car and pi...
# 11  On the memorial anniversary of my friends fath...
# 12            Anxious girlfriend always needs my help
# 13                                              Never
# 14                                       You as a mom
# 15  ex gf was a cutter/suicidal, got her out of he...
# 16  I have helped advise friends who have faced ci...
# 17                     I've helped friends out before
# 18  A friend that is a girl and just talk to her t...
# 19  expressing concern and openness to friends whe...
# 20                 listening to girlfriend's problems
# 21  Friend was thinking about suicide, after a few...
# 22  Having gone through depression and anxiety mys...
# 23  Sometimes my friends bring up issues they are ...
# 24  never i guess people dont see me as a guy they...
# 25  Last year, my best friend was diagnosed with a...
# 26  Cleaning up my friend's campsite and slightly ...
# 27  i listen pretty damn well. better at that as a...
# 28  Helping a friend through dealing with his alco...
# 29  I used to tutor homeless men at a shelter to h...
# ..                                                ...
# 50  I once acted as a resource for someone who was...
# 51  My friend was going through a period of intens...
# 52  I have talked though some major blows in my gi...
# 53               Talking to a friend over a break up.
# 54  I care about other people more than myself so ...
# 55  Over the internet a LOT of people write to me ...
# 56  Friends sometimes come up to me and ask for ad...
# 57  My friend dealt with anxiety and this desire f...
# 58  Simply being there as a friend for somebody wh...
# 59  I've had some friends come to me saying people...
# 60  People calling, talk some sense into them, may...
# 61  Having self harmed in the past,  I shared my e...
# 62          Have worked through problems with friends
# 63  When my friend needed help when she was going ...
# 64  My sister has some pretty severe issues  with ...
# 65                      Helped friends through stuff.
# 66  I helped encourage a friend to go to therapy, ...
# 67  I haven't really met anyone dealing with atten...
# 68  there are too many to remember specifically, b...
# 69  one of my friends was feeling down, so he came...
# 70                                             never.
# 71  I have tried but am absolutely horrable at it ...
# 72  Ex girlfriend had depression and anxiety. I us...
# 73  Always. I don't judge people to much, and can ...
# 74  My grandmother went through some severe depres...
# 75  Now that I've been through it, although i'm no...
# 76  when my best friends mom past away from od'ing...
# 77  As a camp counselor I provide stability in kid...
# 78  My now girlfriend used to have serious addicti...
# 79  The one person I ever talked to it was because...
#
#                                            Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0                                                 NaN         NaN        NaN
# 1                                                 NaN         NaN        NaN
# 2                                                 NaN         NaN        NaN
# 3                                                 NaN         NaN        NaN
# 4                                                             NaN        NaN
# 5                                                 NaN         NaN        NaN
# 6                                                 NaN         NaN        NaN
# 7                                                 NaN         NaN        NaN
# 8                                                 NaN         NaN        NaN
# 9                                                 NaN         NaN        NaN
# 10                                                NaN         NaN        NaN
# 11                                                NaN         NaN        NaN
# 12                                                NaN         NaN        NaN
# 13                                                NaN         NaN        NaN
# 14                                                NaN         NaN        NaN
# 15                                                NaN         NaN        NaN
# 16                                                NaN         NaN        NaN
# 17                                                NaN         NaN        NaN
# 18                                                NaN         NaN        NaN
# 19                                                NaN         NaN        NaN
# 20                                                NaN         NaN        NaN
# 21                                                NaN         NaN        NaN
# 22                                                NaN         NaN        NaN
# 23                                                NaN         NaN        NaN
# 24                                                NaN         NaN        NaN
# 25                                                NaN         NaN        NaN
# 26                                                NaN         NaN        NaN
# 27                                                NaN         NaN        NaN
# 28                                                NaN         NaN        NaN
# 29                                                NaN         NaN        NaN
# ..                                                ...         ...        ...
# 50                                                NaN         NaN        NaN
# 51                                                NaN         NaN        NaN
# 52                                                NaN         NaN        NaN
# 53                                                NaN         NaN        NaN
# 54                                                NaN         NaN        NaN
# 55   because so many people come to me with their ...         NaN
# 56                                                NaN         NaN        NaN
# 57                                                NaN         NaN        NaN
# 58                                                NaN         NaN        NaN
# 59                                                NaN         NaN        NaN
# 60                                                NaN         NaN        NaN
# 61                                                NaN         NaN        NaN
# 62                                                NaN         NaN        NaN
# 63                                                NaN         NaN        NaN
# 64                                                NaN         NaN        NaN
# 65                                                NaN         NaN        NaN
# 66                                                NaN         NaN        NaN
# 67                                                NaN         NaN        NaN
# 68                                                NaN         NaN        NaN
# 69                                                NaN         NaN        NaN
# 70                                                NaN         NaN        NaN
# 71                                                NaN         NaN        NaN
# 72                                                NaN         NaN        NaN
# 73                                                NaN         NaN        NaN
# 74                                                NaN         NaN        NaN
# 75                                                NaN         NaN        NaN
# 76                                                NaN         NaN        NaN
# 77                                                NaN         NaN        NaN
# 78                                                NaN         NaN        NaN
# 79                                                NaN         NaN        NaN
#
#     Unnamed: 6 Unnamed: 7
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN
# 5          NaN        NaN
# 6          NaN        NaN
# 7          NaN        NaN
# 8          NaN        NaN
# 9          NaN        NaN
# 10         NaN        NaN
# 11         NaN        NaN
# 12         NaN        NaN
# 13         NaN        NaN
# 14         NaN        NaN
# 15         NaN        NaN
# 16         NaN        NaN
# 17         NaN        NaN
# 18         NaN        NaN
# 19         NaN        NaN
# 20         NaN        NaN
# 21         NaN        NaN
# 22         NaN        NaN
# 23         NaN        NaN
# 24         NaN        NaN
# 25         NaN        NaN
# 26         NaN        NaN
# 27         NaN        NaN
# 28         NaN        NaN
# 29         NaN        NaN
# ..         ...        ...
# 50         NaN        NaN
# 51         NaN        NaN
# 52         NaN        NaN
# 53         NaN        NaN
# 54         NaN        NaN
# 55         NaN
# 56         NaN        NaN
# 57         NaN        NaN
# 58         NaN        NaN
# 59         NaN        NaN
# 60         NaN        NaN
# 61         NaN        NaN
# 62         NaN        NaN
# 63         NaN        NaN
# 64         NaN        NaN
# 65         NaN        NaN
# 66         NaN        NaN
# 67         NaN        NaN
# 68         NaN        NaN
# 69         NaN        NaN
# 70         NaN        NaN
# 71         NaN        NaN
# 72         NaN        NaN
# 73         NaN        NaN
# 74         NaN        NaN
# 75         NaN        NaN
# 76         NaN        NaN
# 77         NaN        NaN
# 78         NaN        NaN
# 79         NaN        NaN
#
# [80 rows x 8 columns]

# %%
wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(data['response_text']))

print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=900)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f354660ca90>

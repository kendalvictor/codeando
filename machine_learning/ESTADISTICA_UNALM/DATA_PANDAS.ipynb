# %%
import pandas as pd
data = pd.read_csv('whiskies.txt', index_col='RowID')
del data.index.name
data.head(10)
# Out:
#       Distillery  Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  \
# 1      Aberfeldy     2          2      2          0        0      2      1
# 2       Aberlour     3          3      1          0        0      4      3
# 3         AnCnoc     1          3      2          0        0      2      0
# 4         Ardbeg     4          1      4          4        0      0      2
# 5        Ardmore     2          2      2          0        0      1      1
# 6    ArranIsleOf     2          3      1          1        0      1      1
# 7   Auchentoshan     0          2      0          0        0      1      1
# 8      Auchroisk     2          3      1          0        0      2      1
# 9       Aultmore     2          2      1          0        0      1      0
# 10      Balblair     2          3      2          1        0      0      2
#
#     Winey  Nutty  Malty  Fruity  Floral     Postcode   Latitude   Longitude
# ...

# %%
data.median()
# Out:
# Body               2.0
# Sweetness          2.0
# Smoky              1.0
# Medicinal          0.0
# Tobacco            0.0
# Honey              1.0
# Spicy              1.0
# Winey              1.0
# Nutty              2.0
# Malty              2.0
# Fruity             2.0
# Floral             2.0
#  Latitude     319515.0
#  Longitude    839885.0
# dtype: float64

# %%
data.skew()
# Out:
# Body          0.487074
# Sweetness     0.089705
# Smoky         1.067996
# Medicinal     2.064985
# Tobacco       2.436781
# Honey         0.202151
# Spicy        -0.202119
# Winey         1.026478
# Nutty        -0.146307
# Malty        -0.405737
# Fruity       -0.552282
# Floral       -0.178524
#  Latitude    -1.197425
#  Longitude   -0.682041
# dtype: float64

# %%
data.kurtosis()
# Out:
# Body          0.172409
# Sweetness    -0.198721
# Smoky         1.383805
# Medicinal     3.939447
# Tobacco       4.031128
# Honey        -0.002196
# Spicy        -0.533278
# Winey         1.230823
# Nutty         0.159003
# Malty         0.627369
# Fruity        0.229528
# Floral        0.576403
#  Latitude     0.275806
#  Longitude    0.253425
# dtype: float64

# %%
data.describe(include='all')
# Out:
#        Distillery       Body  Sweetness      Smoky  Medicinal    Tobacco  \
# count          86  86.000000  86.000000  86.000000  86.000000  86.000000
# unique         86        NaN        NaN        NaN        NaN        NaN
# top     Dailuaine        NaN        NaN        NaN        NaN        NaN
# freq            1        NaN        NaN        NaN        NaN        NaN
# mean          NaN   2.069767   2.290698   1.534884   0.546512   0.116279
# std           NaN   0.930410   0.717287   0.863613   0.990032   0.322439
# min           NaN   0.000000   1.000000   0.000000   0.000000   0.000000
# 25%           NaN   2.000000   2.000000   1.000000   0.000000   0.000000
# 50%           NaN   2.000000   2.000000   1.000000   0.000000   0.000000
# 75%           NaN   2.000000   3.000000   2.000000   1.000000   0.000000
# max           NaN   4.000000   4.000000   4.000000   4.000000   1.000000
#
#             Honey      Spicy      Winey      Nutty      Malty     Fruity  \
# ...

# %%
val = data.groupby('Distillery')['Malty'].mean()
val
# Out:
# Distillery
# Aberfeldy         2
# Aberlour          3
# AnCnoc            2
# Ardbeg            2
# Ardmore           3
# ArranIsleOf       1
# Auchentoshan      2
# Auchroisk         2
# Aultmore          2
# Balblair          1
# Balmenach         0
# Belvenie          2
# BenNevis          2
# Benriach          2
# Benrinnes         3
# Benromach         2
# Bladnoch          2
# BlairAthol        2
# Bowmore           1
# Bruichladdich     2
# Bunnahabhain      2
# Caol Ila          1
# Cardhu            2
# Clynelish         1
# Craigallechie     2
# Craigganmore      2
# Dailuaine         2
# Dalmore           2
# Dalwhinnie        2
# Deanston          3
#                  ..
# Knochando         1
# Lagavulin         1
# Laphroig          1
# Linkwood          1
# Loch Lomond       2
# Longmorn          3
# Macallan          2
# Mannochmore       1
# Miltonduff        1
# Mortlach          1
# Oban              2
# OldFettercairn    3
# OldPulteney       2
# ...

# %%
region = pd.read_csv('regions.txt')
region.head()
# Out:
#   #####Regions#####
# 0         Highlands
# 1          Speyside
# 2         Highlands
# 3             Islay
# 4         Highlands

# %%
region.describe(include='all')
# Out:
#        #####Regions#####
# count                 86
# unique                 6
# top             Speyside
# freq                  43

# %%
aa = data.iloc[:, 6:10]
aa
# Out:
#     Honey  Spicy  Winey  Nutty
# 1       2      1      2      2
# 2       4      3      2      2
# 3       2      0      0      2
# 4       0      2      0      1
# 5       1      1      1      2
# 6       1      1      1      0
# 7       1      1      0      2
# 8       2      1      2      2
# 9       1      0      0      2
# 10      0      2      0      2
# 11      2      1      3      3
# 12      3      2      1      0
# 13      2      2      0      2
# 14      2      2      0      0
# 15      3      1      1      2
# 16      2      2      1      2
# 17      0      1      1      0
# 18      1      2      2      2
# 19      2      2      1      1
# 20      2      2      1      2
# 21      1      1      1      1
# 22      0      2      0      2
# 23      1      1      0      2
# 24      0      2      0      1
# 25      2      2      1      2
# 26      0      1      0      2
# 27      1      2      2      2
# 28      1      2      2      1
# 29      2      1      0      1
# ...

# %%
data.columns
# Out:
# Index(['Distillery', 'Body', 'Sweetness', 'Smoky', 'Medicinal', 'Tobacco',
#        'Honey', 'Spicy', 'Winey', 'Nutty', 'Malty', 'Fruity', 'Floral',
#        'Postcode', ' Latitude', ' Longitude'],
#       dtype='object')

# %% [raw]
# region.shape, data.shape

# %%
region.shape, data.shape
# Out:
# ((86, 1), (86, 16))

# %%
region
# Out:
#    #####Regions#####
# 0          Highlands
# 1           Speyside
# 2          Highlands
# 3              Islay
# 4          Highlands
# 5            Islands
# 6           Lowlands
# 7           Speyside
# 8           Speyside
# 9          Highlands
# 10          Speyside
# 11          Speyside
# 12         Highlands
# 13          Speyside
# 14          Speyside
# 15          Speyside
# 16          Lowlands
# 17         Highlands
# 18             Islay
# 19             Islay
# 20             Islay
# 21             Islay
# 22          Speyside
# 23         Highlands
# 24          Speyside
# 25          Speyside
# 26          Speyside
# 27         Highlands
# 28         Highlands
# 29         Highlands
# ..               ...
# 56          Speyside
# 57             Islay
# 58             Islay
# 59          Speyside
# 60         Highlands
# 61          Speyside
# 62          Speyside
# 63          Speyside
# 64          Speyside
# 65          Speyside
# 66         Highlands
# ...

# %%
data['region'] = region.iloc[:, 0]

# %%
data.columns
# Out:
# Index(['Distillery', 'Body', 'Sweetness', 'Smoky', 'Medicinal', 'Tobacco',
#        'Honey', 'Spicy', 'Winey', 'Nutty', 'Malty', 'Fruity', 'Floral',
#        'Postcode', ' Latitude', ' Longitude', 'region'],
#       dtype='object')

# %%
data['region']
# Out:
# 1         Speyside
# 2        Highlands
# 3            Islay
# 4        Highlands
# 5          Islands
# 6         Lowlands
# 7         Speyside
# 8         Speyside
# 9        Highlands
# 10        Speyside
# 11        Speyside
# 12       Highlands
# 13        Speyside
# 14        Speyside
# 15        Speyside
# 16        Lowlands
# 17       Highlands
# 18           Islay
# 19           Islay
# 20           Islay
# 21           Islay
# 22        Speyside
# 23       Highlands
# 24        Speyside
# 25        Speyside
# 26        Speyside
# 27       Highlands
# 28       Highlands
# 29       Highlands
# 30        Speyside
#           ...
# 57           Islay
# 58           Islay
# 59        Speyside
# 60       Highlands
# 61        Speyside
# 62        Speyside
# 63        Speyside
# 64        Speyside
# 65        Speyside
# 66       Highlands
# 67       Highlands
# 68       Highlands
# 69        Speyside
# 70       Highlands
# 71         Islands
# 72        Speyside
# ...

# %%
correl = data.corr().transpose()
correl
# Out:
#                 Body  Sweetness     Smoky  Medicinal   Tobacco     Honey  \
# Body        1.000000  -0.136518  0.524032   0.354050  0.168718  0.082031
# Sweetness  -0.136518   1.000000 -0.405897  -0.392017 -0.147871  0.132558
# Smoky       0.524032  -0.405897  1.000000   0.686071  0.365501 -0.195318
# Medicinal   0.354050  -0.392017  0.686071   1.000000  0.425106 -0.396629
# Tobacco     0.168718  -0.147871  0.365501   0.425106  1.000000 -0.275490
# Honey       0.082031   0.132558 -0.195318  -0.396629 -0.275490  1.000000
# Spicy       0.188500  -0.054200  0.231745   0.044903  0.054068  0.139563
# Winey       0.408576   0.115727 -0.028190  -0.202651  0.009097  0.362021
# Nutty       0.126323  -0.032493 -0.023132  -0.113671 -0.117717  0.188492
# Malty      -0.116859  -0.001516 -0.192875  -0.258959 -0.059347  0.310184
# Fruity     -0.013205   0.019820 -0.312970  -0.330975 -0.235145  0.108822
# Floral     -0.461203   0.144987 -0.431663  -0.511323 -0.212375  0.183029
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[10, 10])
plt.pcolor(correl)
plt.colorbar()
plt.show()

# %%
list(correl.index)
# Out:
# ['Body',
#  'Sweetness',
#  'Smoky',
#  'Medicinal',
#  'Tobacco',
#  'Honey',
#  'Spicy',
#  'Winey',
#  'Nutty',
#  'Malty',
#  'Fruity',
#  'Floral',
#  ' Latitude',
#  ' Longitude']

# %%
correl.[]
# Out:
# Help on function show in module matplotlib.pyplot:
#
# show(*args, **kw)
#     Display a figure.
#     When running in ipython with its pylab mode, display all
#     figures and return to the ipython prompt.
#
#     In non-interactive mode, display all figures and block until
#     the figures have been closed; in interactive mode it has no
#     effect unless figures were created prior to a change from
#     non-interactive to interactive mode (not recommended).  In
#     that case it displays the figures but does not block.
#
#     A single experimental keyword argument, *block*, may be
#     set to True or False to override the blocking behavior
#     described above.

# %%
help(plt)
# Out:
# Help on module matplotlib.pyplot in matplotlib:
#
# NAME
#     matplotlib.pyplot
#
# DESCRIPTION
#     `matplotlib.pyplot` is a state-based interface to matplotlib. It provides
#     a MATLAB-like way of plotting.
#
#     pyplot is mainly intended for interactive plots and simple cases of programmatic
#     plot generation::
#
#         import numpy as np
#         import matplotlib.pyplot as plt
#
#         x = np.arange(0, 5, 0.1)
#         y = np.sin(x)
#         plt.plot(x, y)
#
#     The object-oriented API is recommended for more complex plots.
#
# FUNCTIONS
#     acorr(x, hold=None, data=None, **kwargs)
#         Plot the autocorrelation of `x`.
#
#         Parameters
#         ----------
#
#         x : sequence of scalar
#
#         hold : boolean, optional, *deprecated*, default: True
#
#         detrend : callable, optional, default: `mlab.detrend_none`
#             x is detrended by the `detrend` callable. Default is no
#             normalization.
#
# ...
